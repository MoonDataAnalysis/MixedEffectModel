# %% [markdown]
# ## 回顾1-7课，重要的从理论概念与数学原理
#
# ### 2.2 相对精度因子（relative precision factor）

# %% [markdown]
# ### 单水平分组模型的相对精度因子
# ![image.png](attachment:image.png)
#
# - 相对精度因子∆,
#
# ![image-2.png](attachment:image-2.png)
#
# #### 以 Lession2 中的火车轨道实验为例
#
# - 六根铁轨，对每根铁轨测试三次（测量超声波沿铁轨长度传播所需的时间）。
# ![image-3.png](attachment:image-3.png)
# - 相对精度因子∆,
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# #### 以 Lession3 凳子类型的人体工程学实验为例
# - 实验人员记录了九名不同受试者从四种不同类型的凳子上起身所需的力气。
# - 固定效应（helmert contrast）
# ![image.png](attachment:image.png)
# - 随机效应
# ![image-2.png](attachment:image-2.png)
# - 相对精度因子∆,
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### 以 Lession4 女孩正畸生长趋势为例
# - 对 27 名儿童（其中 16 名男孩，11 名女孩）从 8 岁起每隔两年测量一次其脑垂体到翼上颌裂的距离，一直测到 14 岁。
# ![image.png](attachment:image.png)
# - 相对精度因子∆,
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 多层线性混合效应模型的相对精度因子
# - 两层级 MLM
# ![image.png](attachment:image.png)
# #####
# - 三层级 MLM
# ![image-2.png](attachment:image-2.png)
# #####

# %% [markdown]
# #### 以Lession7燕麦品种和氮素水平的裂区实验 为例
# #####
# - 农田被划分为六个区组（blocks），每个区组有三块地（plots）。每块地又被细分为四个子地块（subplots）。
# ![image.png](attachment:image.png)
# #####
# - 固定效应与随机效应
# ![image-2.png](attachment:image-2.png)
#
# - 相对精度因子∆,
# ![image-3.png](attachment:image-3.png)
