# %% [markdown]
# ## 2.2 LME的似然估计（Likelihood Estimation）
# 我们将着重介绍两种常用方法：极大似然法（ML）和限制极大似然法（REML）。

# %% [markdown]
# ### （1）LME 模型
# ![image.png](attachment:image.png)

# %% [markdown]
# ### （2）LME 的似然估计
# ![image.png](attachment:image.png)
#
# #### （2.1）条件概率密度
# ![image-2.png](attachment:image-2.png)
#
# #### （2.2）推导：
# ![image-3.png](attachment:image-3.png)
#
# #### （2.3）优化
# ![image-7.png](attachment:image-7.png)
#
# ### （3）对数似然函数
# ![image-8.png](attachment:image-8.png)
#
# ### （4）优化算法（例如，Expectation-Maximization，EM）

# %%
library(nlme)

# %%
fm1Rail.lme <- lme( travel ~ 1, data = Rail, random = ~ 1 | Rail, control = list( msVerbose = TRUE ) )
# Out:
#   0:     61.048859: -1.81959
#   1:     61.048859: -1.81959

# %% [markdown]
# ### （5）近似分布
# ![image.png](attachment:image.png)

# %% [markdown]
# ### （6）假设检验与置信区间
# #### （6.1）似然比检验
#
# 六名工人在三种不同机器类型上的生产力得分。每名工人使用每台机器三次，因此在每组条件下我们都有三次重复测量的数据 。想了解机器的差异。
# ![image.png](attachment:image.png)

# %%
fm1Machine <- lme( score ~ Machine, data = Machines, random = ~ 1 | Worker )
fm2Machine <- update( fm1Machine, random = ~ 1 | Worker/Machine )

# %%
anova( fm1Machine, fm2Machine )
# Out:
#            call
# fm1Machine lme.formula(fixed = score ~ Machine, data = Machines, random = ~1 |     Worker)
# fm2Machine lme.formula(fixed = score ~ Machine, data = Machines, random = ~1 |     Worker/Machine)
#            Model df AIC      BIC      logLik    Test   L.Ratio  p-value
# fm1Machine 1     5  296.8782 306.5373 -143.4391              NA          NA
# fm2Machine 2     6  227.6876 239.2785 -107.8438 1 vs 2 71.19063 3.24324e-17

# %% [markdown]
# AIC 与 BIC
# ![image.png](attachment:image.png)
# p值显著性
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 固定效应显著性问题

# %%
summary(fm2Machine)
# Out:
# Linear mixed-effects model fit by REML
#   Data: Machines
#        AIC      BIC    logLik
#   227.6876 239.2785 -107.8438
#
# Random effects:
#  Formula: ~1 | Worker
#         (Intercept)
# StdDev:     4.78105
#
#  Formula: ~1 | Machine %in% Worker
#         (Intercept)  Residual
# StdDev:    3.729532 0.9615771
#
# Fixed effects:  score ~ Machine
#                Value Std.Error DF   t-value p-value
# (Intercept) 52.35556  2.485828 36 21.061613  0.0000
# MachineB     7.96667  2.176972 10  3.659518  0.0044
# MachineC    13.91667  2.176972 10  6.392672  0.0001
#  Correlation:
#          (Intr) MachnB
# MachineB -0.438
# MachineC -0.438  0.500
#
# Standardized Within-Group Residuals:
#         Min          Q1         Med          Q3         Max
# -2.26958675 -0.54846580 -0.01070594  0.43936568  2.54005792
#
# Number of Observations: 54
# Number of Groups:
#              Worker Machine %in% Worker
#                   6                  18

# %% [markdown]
# #### (6.2) t 检验
# 固定效应 t 检验
# ![image-3.png](attachment:image-3.png)
# 标准误
# ![image.png](attachment:image.png)
# df
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### （6.3）置信区间
# ![image.png](attachment:image.png)
